# %%
import pandas as pd

# %%
data=pd.read_csv("D:\python class\DTM09\market_data.csv")

# %%
data.head()
# Out:
#   RepName Day of Created_x Customer Type  CustomerId Customer Name  \
# 0   AKASH  11 October 2023         Mason       12082     Saravanan
# 1   AKASH  11 October 2023         Mason       12082     Saravanan
# 2   AKASH  11 October 2023         Mason       12082     Saravanan
# 3   AKASH  11 October 2023         Mason       12082     Saravanan
# 4   AKASH  11 October 2023         Mason       12082     Saravanan
#
#                                        Address 1_x          Area Name  \
# 0  30 Sadhukaramadam 1st Street Banavaram, Kosapet  KOSAPET (VELLORE)
# 1  30 Sadhukaramadam 1st Street Banavaram, Kosapet  KOSAPET (VELLORE)
# 2  30 Sadhukaramadam 1st Street Banavaram, Kosapet  KOSAPET (VELLORE)
# 3  30 Sadhukaramadam 1st Street Banavaram, Kosapet  KOSAPET (VELLORE)
# 4  30 Sadhukaramadam 1st Street Banavaram, Kosapet  KOSAPET (VELLORE)
#
#   City Name District_x StateName_x  ... Rep Name  \
# 0   VELLORE    VELLORE  TAMIL NADU  ...    akash
# ...

# %%
data.columns
# Out:
# Index(['RepName', 'Day of Created_x', 'Customer Type', 'CustomerId',
#        'Customer Name', 'Address 1_x', 'Area Name', 'City Name', 'District_x',
#        'StateName_x', 'MobileNumber_x', 'Latlng_x', 'GST No_x', 'DealerId',
#        'RepName_x', 'Day of Created Date', 'City Name_x', 'Area Name_x',
#        'Dealer Name_x', 'Category Name_x', 'Sub-Category_x', 'Brand Name_x',
#        'Dealer type', 'Rank', 'Sourcing Partner', 'SourcingPartnerType',
#        'Credit Status_x', 'RepName_y', 'Day of Created_y', 'Dealer Name_y',
#        'Address 1_y', 'Area Name_y', 'City Name_y', 'District_y',
#        'StateName_y', 'MobileNumber_y', 'Latlng_y', 'Lot Size',
#        'Customer Rating', 'Credit Rating', 'GST No_y', 'SiteId', 'Rep. Name',
#        'Day of Created (sites)', 'Site Name_x', 'Address1 (sites)',
#        'Area/Town', 'CityName', 'District Name_x', 'Pin Code', 'Lat.Lng.',
#        'MobileNo.', 'Initial Construction Stage', 'Rep Name',
# ...

# %%
data[['Day of Created_x','Day of Created Date','Day of Created_y','Day of Created (sites)','Day of Created (sitebrandmixlines)']]
# Out:
#       Day of Created_x Day of Created Date Day of Created_y  \
# 0      11 October 2023      6 October 2023   6 October 2023
# 1      11 October 2023      6 October 2023   6 October 2023
# 2      11 October 2023      6 October 2023   6 October 2023
# 3      11 October 2023      6 October 2023   6 October 2023
# 4      11 October 2023      6 October 2023   6 October 2023
# ...                ...                 ...              ...
# 14100  19 October 2023     19 October 2023  19 October 2023
# 14101  19 October 2023     19 October 2023  19 October 2023
# 14102  19 October 2023     19 October 2023  19 October 2023
# 14103  19 October 2023     19 October 2023  19 October 2023
# 14104  19 October 2023     19 October 2023  19 October 2023
#
#       Day of Created (sites) Day of Created (sitebrandmixlines)
# 0            11 October 2023                    11 October 2023
# 1            11 October 2023                    11 October 2023
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14105 entries, 0 to 14104
# Data columns (total 63 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   RepName                             14105 non-null  object
#  1   Day of Created_x                    14105 non-null  object
#  2   Customer Type                       14105 non-null  object
#  3   CustomerId                          14105 non-null  int64
#  4   Customer Name                       14105 non-null  object
#  5   Address 1_x                         14105 non-null  object
#  6   Area Name                           14089 non-null  object
#  7   City Name                           14057 non-null  object
#  8   District_x                          14105 non-null  object
#  9   StateName_x                         13993 non-null  object
#  10  MobileNumber_x                      14105 non-null  object
# ...

# %%
df1=data[["CustomerId","Day of Created Date","Sub-Category_y"]]

# %%
df1.columns=["CustomerId","Date","Products"]

# %%
df1
# Out:
#        CustomerId             Date              Products
# 0           12082   6 October 2023                   PPC
# 1           12082   6 October 2023   ELECTRICAL CONDUITS
# 2           12082   6 October 2023                   MCB
# 3           12082   6 October 2023        WIRES & CABLES
# 4           12082   6 October 2023               PLYWOOD
# ...           ...              ...                   ...
# 14100       12686  19 October 2023              TMT BARS
# 14101       12686  19 October 2023  EXTERIOR WALL PAINTS
# 14102       12686  19 October 2023  EXTERIOR WALL PAINTS
# 14103       12686  19 October 2023  INTERIOR WALL PAINTS
# 14104       12686  19 October 2023  INTERIOR WALL PAINTS
#
# [14105 rows x 3 columns]

# %%
df1["Date"]=pd.to_datetime(df1["Date"])
# Out:
# C:\Users\kishore kumar\AppData\Local\Temp\ipykernel_27596\3344398335.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Date"]=pd.to_datetime(df1["Date"])

# %%
df1
# Out:
#        CustomerId       Date              Products
# 0           12082 2023-10-06                   PPC
# 1           12082 2023-10-06   ELECTRICAL CONDUITS
# 2           12082 2023-10-06                   MCB
# 3           12082 2023-10-06        WIRES & CABLES
# 4           12082 2023-10-06               PLYWOOD
# ...           ...        ...                   ...
# 14100       12686 2023-10-19              TMT BARS
# 14101       12686 2023-10-19  EXTERIOR WALL PAINTS
# 14102       12686 2023-10-19  EXTERIOR WALL PAINTS
# 14103       12686 2023-10-19  INTERIOR WALL PAINTS
# 14104       12686 2023-10-19  INTERIOR WALL PAINTS
#
# [14105 rows x 3 columns]

# %%
df1=df1.sort_values(["CustomerId","Date"])

# %%
df1
# Out:
#        CustomerId       Date              Products
# 13141       11883 2023-08-24                   PPC
# 13142       11883 2023-08-24         PIPE FITTINGS
# 13143       11883 2023-08-24                 PIPES
# 13144       11883 2023-08-24              TMT BARS
# 13145       11883 2023-08-24  EXTERIOR WALL PAINTS
# ...           ...        ...                   ...
# 11888       12711 2023-08-25              TMT BARS
# 11889       12711 2023-08-25                 TILES
# 11890       12711 2023-10-04                   PPC
# 11891       12711 2023-10-04              TMT BARS
# 11892       12711 2023-10-04                 TILES
#
# [14105 rows x 3 columns]

# %%
unique_data=df1.groupby(["CustomerId","Date"])["Products"].unique().agg(list).reset_index()
with_duplicate=df1.groupby(["CustomerId","Date"])["Products"].agg(list).reset_index()
# Out:
# C:\Users\kishore kumar\AppData\Local\Temp\ipykernel_27596\710564824.py:1: FutureWarning: using <class 'list'> in Series.agg cannot aggregate and has been deprecated. Use Series.transform to keep behavior unchanged.
#   unique_data=df1.groupby(["CustomerId","Date"])["Products"].unique().agg(list).reset_index()

# %%
unique_data[unique_data["CustomerId"]==12711]
# Out:
#      CustomerId       Date                Products
# 381       12711 2023-08-25  [PPC, TMT BARS, TILES]
# 382       12711 2023-10-04  [PPC, TMT BARS, TILES]

# %%
with_duplicate[with_duplicate["CustomerId"]==12711]
# Out:
#      CustomerId       Date                                           Products
# 381       12711 2023-08-25  [PPC, TMT BARS, TILES, PPC, TMT BARS, TILES, P...
# 382       12711 2023-10-04                             [PPC, TMT BARS, TILES]

# %%
unique_data
# Out:
#      CustomerId       Date                                           Products
# 0         11883 2023-08-24  [PPC, PIPE FITTINGS, PIPES, TMT BARS, EXTERIOR...
# 1         11885 2023-08-30  [PPC, SWITCHES & SOCKETS, WIRES & CABLES, PIPE...
# 2         11889 2023-08-24                                    [PPC, TMT BARS]
# 3         11889 2023-10-31                                    [PPC, TMT BARS]
# 4         11891 2023-09-01  [PPC, SWITCHES & SOCKETS, WIRES & CABLES, TMT ...
# ..          ...        ...                                                ...
# 378       12695 2023-08-24                                    [PPC, TMT BARS]
# 379       12695 2023-10-31                                    [PPC, TMT BARS]
# 380       12698 2023-10-09                                    [PPC, TMT BARS]
# 381       12711 2023-08-25                             [PPC, TMT BARS, TILES]
# 382       12711 2023-10-04                             [PPC, TMT BARS, TILES]
#
# [383 rows x 3 columns]

# %%
len(unique_data["CustomerId"].unique())
# Out:
# 246

# %%
df1.groupby(["CustomerId","Date","Products"]).size().reset_index(name="Counts").sort_values("Counts",ascending=False)
# Out:
#       CustomerId       Date                   Products  Counts
# 634        12223 2023-09-01                   TMT BARS     108
# 632        12223 2023-09-01                        PPC     108
# 217        12031 2023-09-05                        PPC     105
# 84         11928 2023-09-06                        PPC      92
# 358        12099 2023-09-01  SWITCH GEAR & ACCESSORIES      72
# ...          ...        ...                        ...     ...
# 573        12185 2023-10-31                        PPC       1
# 572        12185 2023-10-31                      PIPES       1
# 571        12185 2023-10-31              PIPE FITTINGS       1
# 570        12185 2023-10-31       INTERIOR WALL PAINTS       1
# 1412       12711 2023-10-04                   TMT BARS       1
#
# [1413 rows x 4 columns]

# %%
unique_data
# Out:
#      CustomerId       Date                                           Products
# 0         11883 2023-08-24  [PPC, PIPE FITTINGS, PIPES, TMT BARS, EXTERIOR...
# 1         11885 2023-08-30  [PPC, SWITCHES & SOCKETS, WIRES & CABLES, PIPE...
# 2         11889 2023-08-24                                    [PPC, TMT BARS]
# 3         11889 2023-10-31                                    [PPC, TMT BARS]
# 4         11891 2023-09-01  [PPC, SWITCHES & SOCKETS, WIRES & CABLES, TMT ...
# ..          ...        ...                                                ...
# 378       12695 2023-08-24                                    [PPC, TMT BARS]
# 379       12695 2023-10-31                                    [PPC, TMT BARS]
# 380       12698 2023-10-09                                    [PPC, TMT BARS]
# 381       12711 2023-08-25                             [PPC, TMT BARS, TILES]
# 382       12711 2023-10-04                             [PPC, TMT BARS, TILES]
#
# [383 rows x 3 columns]

# %%
df2=data[["CustomerId","Day of Created Date","Sub-Category_y","Credit Rating"]]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df2["Credit Rating"]=le.fit_transform(df2["Credit Rating"])
# Out:
# C:\Users\kishore kumar\AppData\Local\Temp\ipykernel_27596\4286372637.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Credit Rating"]=le.fit_transform(df2["Credit Rating"])

# %%
df2
# Out:
#        CustomerId Day of Created Date        Sub-Category_y  Credit Rating
# 0           12082      6 October 2023                   PPC              5
# 1           12082      6 October 2023   ELECTRICAL CONDUITS              5
# 2           12082      6 October 2023                   MCB              5
# 3           12082      6 October 2023        WIRES & CABLES              5
# 4           12082      6 October 2023               PLYWOOD              5
# ...           ...                 ...                   ...            ...
# 14100       12686     19 October 2023              TMT BARS              5
# 14101       12686     19 October 2023  EXTERIOR WALL PAINTS              5
# 14102       12686     19 October 2023  EXTERIOR WALL PAINTS              5
# 14103       12686     19 October 2023  INTERIOR WALL PAINTS              5
# 14104       12686     19 October 2023  INTERIOR WALL PAINTS              5
#
# [14105 rows x 4 columns]

# %%
df_2=df2.groupby("CustomerId")["Credit Rating"].sum().reset_index()

# %%
df_2
# Out:
#      CustomerId  Credit Rating
# 0         11883            120
# 1         11885            480
# 2         11889             80
# 3         11891           1340
# 4         11892            255
# ..          ...            ...
# 241       12689            120
# 242       12690             60
# 243       12695             80
# 244       12698             60
# 245       12711             45
#
# [246 rows x 2 columns]

# %%
df_2=df_2.sort_values("CustomerId",ascending=True)

# %%
df=unique_data.sort_values("CustomerId",ascending=True)

# %%
df
# Out:
#      CustomerId       Date                                           Products
# 0         11883 2023-08-24  [PPC, PIPE FITTINGS, PIPES, TMT BARS, EXTERIOR...
# 1         11885 2023-08-30  [PPC, SWITCHES & SOCKETS, WIRES & CABLES, PIPE...
# 2         11889 2023-08-24                                    [PPC, TMT BARS]
# 3         11889 2023-10-31                                    [PPC, TMT BARS]
# 4         11891 2023-09-01  [PPC, SWITCHES & SOCKETS, WIRES & CABLES, TMT ...
# ..          ...        ...                                                ...
# 378       12695 2023-08-24                                    [PPC, TMT BARS]
# 379       12695 2023-10-31                                    [PPC, TMT BARS]
# 380       12698 2023-10-09                                    [PPC, TMT BARS]
# 381       12711 2023-08-25                             [PPC, TMT BARS, TILES]
# 382       12711 2023-10-04                             [PPC, TMT BARS, TILES]
#
# [383 rows x 3 columns]

# %%
df["Rating"]=df_2["Credit Rating"]

# %%
df.head()
# Out:
#    CustomerId       Date                                           Products  \
# 0       11883 2023-08-24  [PPC, PIPE FITTINGS, PIPES, TMT BARS, EXTERIOR...
# 1       11885 2023-08-30  [PPC, SWITCHES & SOCKETS, WIRES & CABLES, PIPE...
# 2       11889 2023-08-24                                    [PPC, TMT BARS]
# 3       11889 2023-10-31                                    [PPC, TMT BARS]
# 4       11891 2023-09-01  [PPC, SWITCHES & SOCKETS, WIRES & CABLES, TMT ...
#
#    Rating
# 0   120.0
# 1   480.0
# 2    80.0
# 3  1340.0
# 4   255.0

# %%
df['ProductsID'] = df['Products'].apply(lambda x: hash(tuple(x)))

# %%
df.head()
# Out:
#    CustomerId       Date                                           Products  \
# 0       11883 2023-08-24  [PPC, PIPE FITTINGS, PIPES, TMT BARS, EXTERIOR...
# 1       11885 2023-08-30  [PPC, SWITCHES & SOCKETS, WIRES & CABLES, PIPE...
# 2       11889 2023-08-24                                    [PPC, TMT BARS]
# 3       11889 2023-10-31                                    [PPC, TMT BARS]
# 4       11891 2023-09-01  [PPC, SWITCHES & SOCKETS, WIRES & CABLES, TMT ...
#
#    Rating           ProductsID
# 0   120.0 -3803327562118712071
# 1   480.0  7780375636503449750
# 2    80.0 -4739346750386941242
# 3  1340.0 -4739346750386941242
# 4   255.0  5735752584957157341

# %%
from surprise import Dataset,Reader,SVD
from surprise.model_selection import train_test_split

# %%
readed=Reader(line_format="user item rating",rating_scale=(0,1))

# %%
df.fillna(0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 383 entries, 0 to 382
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerId  383 non-null    int64
#  1   Date        383 non-null    datetime64[ns]
#  2   Products    383 non-null    object
#  3   Rating      383 non-null    float64
#  4   ProductsID  383 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(1)
# memory usage: 18.0+ KB

# %%
data_for_sur = Dataset.load_from_df(df[["CustomerId","ProductsID","Rating"]],readed)

# %%
data_for_sur

# %%
train_data,test_data=train_test_split(data_for_sur,test_size=0.2)

# %%
data
# Out:
#       RepName Day of Created_x Customer Type  CustomerId  \
# 0       AKASH  11 October 2023         Mason       12082
# 1       AKASH  11 October 2023         Mason       12082
# 2       AKASH  11 October 2023         Mason       12082
# 3       AKASH  11 October 2023         Mason       12082
# 4       AKASH  11 October 2023         Mason       12082
# ...       ...              ...           ...         ...
# 14100  VENKAT  19 October 2023         Mason       12686
# 14101  VENKAT  19 October 2023         Mason       12686
# 14102  VENKAT  19 October 2023         Mason       12686
# 14103  VENKAT  19 October 2023         Mason       12686
# 14104  VENKAT  19 October 2023         Mason       12686
#
#                           Customer Name  \
# 0                             Saravanan
# 1                             Saravanan
# 2                             Saravanan
# 3                             Saravanan
# 4                             Saravanan
# ...

# %%
model=SVD()

# %%
model.fit(train_data)

# %%
from itertools import chain

# %%
def show_recom(cust_id,number_of_rec):
    products_overall=df["ProductsID"].unique() # collecting al the productid
    procust_bought=df[df["CustomerId"]==cust_id]["ProductsID"].values #finding the number of products purchased by the customer
    prod_used_for_predict=[i for i in products_overall if i not in procust_bought] # not purchased by the customer
    predict_recom=[(prod,model.predict(cust_id,prod).est)for prod in prod_used_for_predict] #products and rating of the product(.est)

    output_recom= [df[df["ProductsID"]==i_d]["Products"].values[0] for i_d,a in predict_recom[:number_of_rec]]
    out_list =list(chain.from_iterable(output_recom))
    out_list=list(set(out_list))
    return out_list

# %%
show_recom(11891,9)
# Out:
# ['MCB',
#  'PIPES',
#  'PPC',
#  'PIPE FITTINGS',
#  'EXTERIOR WALL PAINTS',
#  'TILES',
#  'TMT BARS',
#  'SWITCHES & SOCKETS',
#  'PLYWOOD',
#  'INTERIOR WALL PAINTS',
#  'WIRES & CABLES',
#  'SWITCH GEAR & ACCESSORIES',
#  'ELECTRICAL CONDUITS']
